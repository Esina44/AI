# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("Student_Performance_630a34a7-d685-4b03-a413-fbb1bcce8deb_212501_.csv")
df2 = pd.read_csv('marks.csv')

# %%
print(df)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
print("Shape of the dataset(rows and columns)")
print(df.shape)

print("\nMissing value in each column")
print(df.isnull().sum())

print("\nNumber of unique vakues per column: ")
print(df.nunique())

print("\nColumn Names")
print(df.columns)
# Out:
# Shape of the dataset(rows and columns)
# (10000, 6)
#
# Missing value in each column
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64
#
# Number of unique vakues per column:
# Hours Studied                        9
# Previous Scores                     60
# Extracurricular Activities           2
# Sleep Hours                          6
# Sample Question Papers Practiced    10
# Performance Index                   91
# dtype: int64
#
# Column Names
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['Hours Studied'], df['Performance Index'])
plt.title("Hours Studies vs performance Index")
plt.xlabel("Hours studies")
plt.ylabel("Perfomance Index")
plt.grid(True)
plt.show()

# %%
df.boxplot()
plt.title("Box plot for all numeric features")
plt.ylabel("Values")
plt.grid(True)

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined
